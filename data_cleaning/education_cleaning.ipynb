# %%
import pandas as pd

# %%
# read in data 
education_data = pd.read_csv('../data/EdStatsData.csv') 
education_data.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 4  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
#
#         1970       1971       1972       1973       1974      1975  ...  2060  \
# 0        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# 1        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# 2        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# ...

# %%
# Print column names
print("Column Names:")
print(education_data.columns)
# Out:
# Column Names:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045',
#        '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090',
#        '2095', '2100', 'Unnamed: 69'],
#       dtype='object')

# %%
# Specify the columns to keep
columns_to_keep = ['Country Name', 'Country Code', 'Indicator Name', '2010', '2011', '2012', '2013', '2014']

# Subset the DataFrame to keep only the specified columns
education_data = education_data[columns_to_keep]

# Display the DataFrame after subsetting
print("\nDataFrame after keeping selected columns:")
print(education_data.head())
# Out:
# DataFrame after keeping selected columns:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name       2010      2011  \
# 0  Adjusted net enrolment rate, lower secondary, ...        NaN       NaN
# 1  Adjusted net enrolment rate, lower secondary, ...        NaN       NaN
# 2  Adjusted net enrolment rate, lower secondary, ...        NaN       NaN
# 3  Adjusted net enrolment rate, lower secondary, ...        NaN       NaN
# 4  Adjusted net enrolment rate, primary, both sex...  85.211998  85.24514
#
#         2012      2013       2014
# 0        NaN       NaN        NaN
# 1        NaN       NaN        NaN
# 2        NaN       NaN        NaN
# 3        NaN       NaN        NaN
# 4  86.101669  85.51194  85.320152

# %%
# Print unique values in the 'Indicator Name' column
unique_indicators = education_data['Indicator Name'].unique()

print("\nUnique Indicator Names:")
for indicator in unique_indicators:
    print(indicator)
# Out:
# Unique Indicator Names:
# Adjusted net enrolment rate, lower secondary, both sexes (%)
# Adjusted net enrolment rate, lower secondary, female (%)
# Adjusted net enrolment rate, lower secondary, gender parity index (GPI)
# Adjusted net enrolment rate, lower secondary, male (%)
# Adjusted net enrolment rate, primary, both sexes (%)
# Adjusted net enrolment rate, primary, female (%)
# Adjusted net enrolment rate, primary, gender parity index (GPI)
# Adjusted net enrolment rate, primary, male (%)
# Adjusted net enrolment rate, upper secondary, both sexes (%)
# Adjusted net enrolment rate, upper secondary, female (%)
# Adjusted net enrolment rate, upper secondary, gender parity index (GPI)
# Adjusted net enrolment rate, upper secondary, male (%)
# Adjusted net intake rate to Grade 1 of primary education, both sexes (%)
# Adjusted net intake rate to Grade 1 of primary education, female (%)
# Adjusted net intake rate to Grade 1 of primary education, gender parity index (GPI)
# ...

# %%
# List of indicator names to keep
indicators_to_keep = [
    'Gross enrolment ratio, lower secondary, female (%)',
    'Gross enrolment ratio, lower secondary, male (%)',
    'Gross enrolment ratio, post-secondary non-tertiary, female (%)',
    'Gross enrolment ratio, post-secondary non-tertiary, male (%)',
    'Gross enrolment ratio, pre-primary, female (%)',
    'Gross enrolment ratio, pre-primary, male (%)',
    'Gross enrolment ratio, primary and lower secondary, female (%)',
    'Gross enrolment ratio, primary and lower secondary, male (%)',
    'Gross enrolment ratio, primary and secondary, female (%)',
    'Gross enrolment ratio, primary and secondary, male (%)',
    'Gross enrolment ratio, primary to tertiary, female (%)',
    'Gross enrolment ratio, primary to tertiary, male (%)',
    'Gross enrolment ratio, primary, female (%)',
    'Gross enrolment ratio, primary, male (%)',
    'Gross enrolment ratio, secondary, female (%)',
    'Gross enrolment ratio, secondary, male (%)',
    'Gross enrolment ratio, tertiary, female (%)',
    'Gross enrolment ratio, tertiary, male (%)',
    'Gross enrolment ratio, upper secondary, female (%)',
    'Gross enrolment ratio, upper secondary, male (%)',
    'GNI (current US$)',
    'GNI per capita, Atlas method (current US$)',
    'GDP per capita (current US$)',
    'Government expenditure in educational institutions as % of GDP (%)'
]

# Filter the DataFrame to keep only the specified indicator names
filtered_education_data = education_data[education_data['Indicator Name'].isin(indicators_to_keep)]

# Display the filtered DataFrame
print("\nDataFrame after filtering for specific indicators:")
print(filtered_education_data.head())
# Out:
# DataFrame after filtering for specific indicators:
#      Country Name Country Code                                 Indicator Name  \
# 1245   Arab World          ARB                   GDP per capita (current US$)
# 1249   Arab World          ARB             GDP, PPP (current international $)
# 1250   Arab World          ARB                              GNI (current US$)
# 1251   Arab World          ARB     GNI per capita, Atlas method (current US$)
# 1252   Arab World          ARB  GNI per capita, PPP (current international $)
#
#               2010          2011          2012          2013  2014
# 1245  6.032962e+03  7.005480e+03  7.571402e+03  7.715999e+03   NaN
# 1249  5.022945e+12  5.265230e+12  5.696577e+12  5.935614e+12   NaN
# 1250  2.072484e+12  2.515669e+12  2.755869e+12  2.846448e+12   NaN
# 1251  5.913745e+03  6.305644e+03  7.196533e+03           NaN   NaN
# 1252  1.428402e+04  1.499616e+04  1.584650e+04  1.614156e+04   NaN

# %%
# file path
output_file_path = '../cleaned_data/filtered_education_data.csv'

# Save the filtered DataFrame to a CSV file
filtered_education_data.to_csv(output_file_path, index=False)

print("Filtered data saved to", output_file_path)
# Out:
# Filtered data saved to ../cleaned_data/filtered_education_data.csv
